# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiourzedojunior/transfer_learning/blob/main/transfer_learning_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import random
import numpy as np
import keras

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model

# Unzipping the dataset
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/DIO/ML specialist/caltech-101.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/caltech-101')

# List the contents of the extracted directory
for dirname, _, filenames in os.walk('/content/caltech-101'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Extracting the tar.gz file
import tarfile
with tarfile.open('/content/caltech-101/caltech-101/101_ObjectCategories.tar.gz', 'r:gz') as tar:
    tar.extractall(path='/content/caltech-101/')

# Verifying the extraction
root = os.path.join('/content/caltech-101/', '101_ObjectCategories')

if os.path.exists(root):
    print("Extraction successful. Directory exists.")
else:
    print("Directory does not exist. Check the extraction path.")

# List of categories to exclude
exclude = ['BACKGROUND_Google', 'Motorbikes', 'airplanes', 'Faces_easy', 'Faces']

# Listing and filtering categories
categories = [os.path.join(root, category) for category in os.listdir(root) if os.path.isdir(os.path.join(root, category))]
categories = [category for category in categories if os.path.basename(category) not in exclude]

print("Selected categories:")
for category in categories:
    print(category)

# Function to load and preprocess images
def get_image(path):
    img = image.load_img(path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return img, x

# Loading all images
data = []
for c, category in enumerate(categories):
    images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(category) for f in filenames if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
    for img_path in images:
        img, x = get_image(img_path)
        data.append({'x': np.array(x[0]), 'y': c})

# Counting the number of classes
num_classes = len(categories)

# Shuffling the data
random.shuffle(data)

# Splitting the data into training, validation, and test sets
train_split = 0.7  # 70% for training
val_split = 0.15   # 15% for validation
test_split = 0.15  # 15% for testing

idx_val = int(train_split * len(data))
idx_test = int((train_split + val_split) * len(data))

train = data[:idx_val]
val = data[idx_val:idx_test]
test = data[idx_test:]

print(f"Training samples: {len(train)}")
print(f"Validation samples: {len(val)}")
print(f"Test samples: {len(test)}")

# Separating data and labels
x_train, y_train = np.array([t["x"] for t in train]), [t["y"] for t in train]
x_val, y_val = np.array([t["x"] for t in val]), [t["y"] for t in val]
x_test, y_test = np.array([t["x"] for t in test]), [t["y"] for t in test]

# Normalizing data and converting labels to one-hot encoding
x_train = x_train.astype('float32') / 255.
x_val = x_val.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"Finished loading {len(data)} images from {num_classes} categories")
print(f"Training/Validation/Test split: {len(x_train)}, {len(x_val)}, {len(x_test)}")
print(f"Training data shape: {x_train.shape}")
print(f"Training labels shape: {y_train.shape}")

# Displaying some random images
images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(root) for f in filenames if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
idx = [int(len(images) * random.random()) for i in range(8)]
imgs = [image.load_img(images[i], target_size=(224, 224)) for i in idx]
concat_image = np.concatenate([np.asarray(img) for img in imgs], axis=1)
plt.figure(figsize=(16, 4))
plt.imshow(concat_image)
plt.show()

# Building the CNN model
model = Sequential()
print("Input dimensions: ", x_train.shape[1:])

model.add(Conv2D(32, (3, 3), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=10,
                    validation_data=(x_val, y_val))

# Plotting validation loss and accuracy
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"])
ax.set_title("Validation Loss")
ax.set_xlabel("Epochs")

ax2 = fig.add_subplot(122)
ax2.plot(history.history["val_accuracy"])
ax2.set_title("Validation Accuracy")
ax2.set_xlabel("Epochs")
ax2.set_ylim(0, 1)

plt.show()

# Evaluating the model on the test set
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

# Fine-tuning with VGG16 pre-trained model
vgg = keras.applications.VGG16(weights='imagenet', include_top=True)
vgg.summary()

inp = vgg.input
new_classification_layer = Dense(num_classes, activation='softmax')(vgg.layers[-2].output)
model_new = Model(inp, new_classification_layer)

for layer in model_new.layers[:-1]:
    layer.trainable = False

model_new.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

model_new.summary()

history2 = model_new.fit(x_train, y_train,
                         batch_size=128,
                         epochs=10,
                         validation_data=(x_val, y_val))

# Plotting validation loss and accuracy for the fine-tuned model
fig = plt.figure(figsize=(16, 4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"], label="Initial Model")
ax.plot(history2.history["val_loss"], label="Fine-tuned Model")
ax.set_title("Validation Loss")
ax.set_xlabel("Epochs")
ax.legend()

ax2 = fig.add_subplot(122)
ax2.plot(history.history["val_accuracy"], label="Initial Model")
ax2.plot(history2.history["val_accuracy"], label="Fine-tuned Model")
ax2.set_title("Validation Accuracy")
ax2.set_xlabel("Epochs")
ax2.set_ylim(0, 1)
ax2.legend()

plt.show()

# Evaluating the fine-tuned model on the test set
loss, accuracy = model_new.evaluate(x_test, y_test, verbose=0)
print('Test loss (fine-tuned):', loss)
print('Test accuracy (fine-tuned):', accuracy)

# Predicting probabilities for a new image
image_path = '/content/caltech-101/101_ObjectCategories/airplanes/image_0003.jpg'
img, x = get_image(image_path)
probabilities = model_new.predict([x])

print(probabilities)
# Out:
# Mounted at /content/drive
# /content/caltech-101/caltech-101/101_ObjectCategories.tar.gz
# /content/caltech-101/caltech-101/show_annotation.m
# /content/caltech-101/caltech-101/Annotations.tar
# /content/caltech-101/__MACOSX/._caltech-101
# /content/caltech-101/__MACOSX/caltech-101/._101_ObjectCategories.tar.gz
# /content/caltech-101/__MACOSX/caltech-101/._Annotations.tar
# /content/caltech-101/__MACOSX/caltech-101/._show_annotation.m
# Extraction successful. Directory exists.
# Selected categories:
# /content/caltech-101/101_ObjectCategories/stop_sign
# /content/caltech-101/101_ObjectCategories/minaret
# /content/caltech-101/101_ObjectCategories/octopus
# /content/caltech-101/101_ObjectCategories/elephant
# /content/caltech-101/101_ObjectCategories/cellphone
# /content/caltech-101/101_ObjectCategories/butterfly
# /content/caltech-101/101_ObjectCategories/euphonium
# /content/caltech-101/101_ObjectCategories/crocodile
# /content/caltech-101/101_ObjectCategories/ant
# ...

# %% [markdown]
# ### Code Analysis and Explanation
#
# #### 1. **Mounting Google Drive and Preparing the Dataset**
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# ```
# - This mounts your Google Drive in Colab, allowing you to access files stored in your Drive.
#
# ```python
# import zipfile
# with zipfile.ZipFile('/content/drive/MyDrive/DIO/ML specialist/caltech-101.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/caltech-101')
# ```
# - The code extracts a ZIP file (the dataset) from Google Drive to a specified directory in Colab.
#
# #### 2. **Unzipping and Organizing the Dataset**
#
# ```python
# import os
# import tarfile
# with tarfile.open('/content/caltech-101/caltech-101/101_ObjectCategories.tar.gz', 'r:gz') as tar:
#     tar.extractall(path='/content/caltech-101/')
# ```
# - Here, the code extracts a tar.gz file containing the dataset into a directory for further use.
#
# ```python
# root = os.path.join('/content/caltech-101/', '101_ObjectCategories')
#
# if os.path.exists(root):
#     print("Extraction successful. Directory exists.")
# else:
#     print("Directory does not exist. Check the extraction path.")
# ```
# - This code checks if the extraction was successful by verifying the existence of the directory.
#
# #### 3. **Filtering and Loading the Images**
#
# ```python
# exclude = ['BACKGROUND_Google', 'Motorbikes', 'airplanes', 'Faces_easy', 'Faces']
# ```
# - Some categories are excluded from the dataset.
#
# ```python
# categories = [os.path.join(root, category) for category in os.listdir(root) if os.path.isdir(os.path.join(root, category))]
# categories = [category for category in categories if os.path.basename(category) not in exclude]
# ```
# - The code lists and filters the categories (folders) in the dataset, excluding the ones specified.
#
# ```python
# def get_image(path):
#     img = image.load_img(path, target_size=(224, 224))
#     x = image.img_to_array(img)
#     x = np.expand_dims(x, axis=0)
#     x = preprocess_input(x)
#     return img, x
# ```
# - This function loads and preprocesses an image to a size of 224x224 pixels, which is a standard input size for many CNN models.
#
# #### 4. **Data Preparation**
#
# ```python
# data = []
# for c, category in enumerate(categories):
#     images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(category) for f in filenames if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
#     for img_path in images:
#         img, x = get_image(img_path)
#         data.append({'x': np.array(x[0]), 'y': c})
# ```
# - This code loads all images in the selected categories, preprocesses them, and stores them in a list with their corresponding category labels.
#
# #### 5. **Data Splitting**
#
# ```python
# random.shuffle(data)
# ```
# - The data is shuffled randomly to ensure that the training, validation, and test sets are representative.
#
# ```python
# train_split = 0.7
# val_split = 0.15
# test_split = 0.15
# ```
# - The dataset is split into 70% training, 15% validation, and 15% testing data.
#
# #### 6. **Data Normalization and One-Hot Encoding**
#
# ```python
# x_train, y_train = np.array([t["x"] for t in train]), [t["y"] for t in train]
# x_val, y_val = np.array([t["x"] for t in val]), [t["y"] for t in val]
# x_test, y_test = np.array([t["x"] for t in test]), [t["y"] for t in test]
# ```
# - This separates the data and labels into training, validation, and testing sets.
#
# ```python
# x_train = x_train.astype('float32') / 255.
# x_val = x_val.astype('float32') / 255.
# x_test = x_test.astype('float32') / 255.
# ```
# - The images are normalized by dividing pixel values by 255.
#
# ```python
# y_train = keras.utils.to_categorical(y_train, num_classes)
# y_val = keras.utils.to_categorical(y_val, num_classes)
# y_test = keras.utils.to_categorical(y_test, num_classes)
# ```
# - The labels are converted into one-hot encoding for multi-class classification.
#
# #### 7. **Building the CNN Model**
#
# ```python
# model = Sequential()
# model.add(Conv2D(32, (3, 3), input_shape=x_train.shape[1:]))
# ...
# model.add(Activation('softmax'))
# ```
# - A Sequential Convolutional Neural Network (CNN) model is built, consisting of several convolutional layers followed by max pooling, dropout, flattening, dense layers, and a softmax output layer.
#
# ```python
# model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
#               metrics=['accuracy'])
# ```
# - The model is compiled with categorical cross-entropy loss, Adam optimizer, and accuracy as the metric.
#
# #### 8. **Training the CNN Model**
#
# ```python
# history = model.fit(x_train, y_train,
#                     batch_size=128,
#                     epochs=10,
#                     validation_data=(x_val, y_val))
# ```
# - The model is trained for 10 epochs with a batch size of 128, using the training set and validating on the validation set.
#
# #### 9. **Evaluating the Model**
#
# ```python
# loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
# print('Test loss:', loss)
# print('Test accuracy:', accuracy)
# ```
# - The model is evaluated on the test set, and the test loss and accuracy are printed.
#
# #### 10. **Fine-Tuning with VGG16**
#
# ```python
# vgg = keras.applications.VGG16(weights='imagenet', include_top=True)
# ...
# model_new = Model(inp, new_classification_layer)
# ```
# - The code loads a pre-trained VGG16 model and fine-tunes it by replacing the final classification layer with one that matches the number of categories in your dataset.
#
# ```python
# for layer in model_new.layers[:-1]:
#     layer.trainable = False
# ```
# - All layers except the last one are frozen to prevent them from being updated during training.
#
# #### 11. **Evaluating the Fine-Tuned Model**
#
# ```python
# loss, accuracy = model_new.evaluate(x_test, y_test, verbose=0)
# print('Test loss (fine-tuned):', loss)
# print('Test accuracy (fine-tuned):', accuracy)
# ```
# - The fine-tuned model is evaluated on the test set, and the results are printed.
#
# ### Results Analysis
#
# - **Initial Model**: The initial CNN model achieved a test accuracy of about 44%, indicating it could recognize the categories but with limited success due to the complexity of the dataset.
#
# - **Fine-Tuned Model**: After fine-tuning with VGG16, the test accuracy significantly improved to around 71%, demonstrating the effectiveness of transfer learning with pre-trained models.
#
# ### Using Personal Images for Training
#
# To use personal images with this code, follow these steps:
#
# 1. **Organize Your Images**:
#    - Store your images in separate folders, each named according to the category (e.g., `Dog`, `Cat`, etc.).
#    - Ensure that all images are in `.jpg`, `.jpeg`, or `.png` format.
#
# 2. **Upload Images to Google Drive**:
#    - Upload your image folders to a directory in Google Drive, just like the dataset used in the code.
#
# 3. **Modify the Paths**:
#    - Update the path in the code where the dataset is being extracted and loaded, pointing it to the location of your personal images in Google Drive.
#
# 4. **Adjust Categories**:
#    - Modify the `exclude` list or the categories you want to include, based on the structure of your dataset.
#
# 5. **Train the Model**:
#    - Run the code with your dataset. You may need to adjust the number of epochs, batch size, or layers of the CNN based on the size and complexity of your dataset.
#
# 6. **Prediction**:
#    - After training, you can use the trained model to predict the category of any new image by using the provided prediction code snippet.
#
# This process will allow you to train a CNN or fine-tune a pre-trained model using your personal image collection, enabling you to build a custom image classification model tailored to your data.
